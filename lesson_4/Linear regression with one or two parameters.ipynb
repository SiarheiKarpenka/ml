# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
#%matplotlib inline

# %% [markdown]
# ## Чтение исходного файла

# %%
with open("E:\study\ml\ml\lesson_4\house prices dataset.txt") as f:
    data = f.readlines()

# %%
def proc(string):
    '''
    parse string with data from file
    '''
    return string.split(',')[1].strip().replace(';', '')

# %% [markdown]
# ## Создание DataFrame объекта

# %%
columns = [proc(data[i]) for i in range(42,54)]
columns[0] += ' in hundreds of dollars'

df = pd.DataFrame([data[i].split()[1:] for i in range(54,82)], columns=columns)
# output dataframe first 10 entrances
df.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>the local selling prices in hundreds of dollars</th>
#       <th>the number of bathrooms</th>
#       <th>the area of the site in thousands of square feet</th>
#       <th>the size of the living space in thousands of square feet</th>
#       <th>the number of garages</th>
#       <th>the number of rooms</th>
#       <th>the number of bedrooms</th>
#       <th>the age in years</th>
#       <th>construction type</th>
#       <th>architecture type</th>
#       <th>number of fire places.</th>
#       <th>selling price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4.9176</td>
#       <td>1.0</td>
#       <td>3.4720</td>
#       <td>0.998</td>
#       <td>1.0</td>
#       <td>7</td>
#       <td>4</td>
#       <td>42</td>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>25.9</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.0208</td>
#       <td>1.0</td>
#       <td>3.5310</td>
#       <td>1.500</td>
#       <td>2.0</td>
#       <td>7</td>
#       <td>4</td>
#       <td>62</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>29.5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.5429</td>
#       <td>1.0</td>
#       <td>2.2750</td>
#       <td>1.175</td>
#       <td>1.0</td>
#       <td>6</td>
#       <td>3</td>
#       <td>40</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>27.9</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.5573</td>
#       <td>1.0</td>
#       <td>4.0500</td>
#       <td>1.232</td>
#       <td>1.0</td>
#       <td>6</td>
#       <td>3</td>
#       <td>54</td>
#       <td>4</td>
#       <td>1</td>
#       <td>0</td>
#       <td>25.9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.0597</td>
#       <td>1.0</td>
#       <td>4.4550</td>
#       <td>1.121</td>
#       <td>1.0</td>
#       <td>6</td>
#       <td>3</td>
#       <td>42</td>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>29.9</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3.8910</td>
#       <td>1.0</td>
#       <td>4.4550</td>
#       <td>0.988</td>
#       <td>1.0</td>
#       <td>6</td>
#       <td>3</td>
#       <td>56</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>29.9</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>5.8980</td>
#       <td>1.0</td>
#       <td>5.8500</td>
#       <td>1.240</td>
#       <td>1.0</td>
#       <td>7</td>
#       <td>3</td>
#       <td>51</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>30.9</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>5.6039</td>
#       <td>1.0</td>
#       <td>9.5200</td>
#       <td>1.501</td>
#       <td>0.0</td>
#       <td>6</td>
#       <td>3</td>
#       <td>32</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>28.9</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>16.4202</td>
#       <td>2.5</td>
#       <td>9.8000</td>
#       <td>3.420</td>
#       <td>2.0</td>
#       <td>10</td>
#       <td>5</td>
#       <td>42</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>84.9</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>14.4598</td>
#       <td>2.5</td>
#       <td>12.8000</td>
#       <td>3.000</td>
#       <td>2.0</td>
#       <td>9</td>
#       <td>5</td>
#       <td>14</td>
#       <td>4</td>
#       <td>1</td>
#       <td>1</td>
#       <td>82.9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# **в качестве признака возьмем размер жилой площади в футах квадратных (столбец 4)**
#
# Последний столбец - это целевая переменная, y

# %%
# get the size of the living space in thousands of square feet
X = df[df.columns[3]].values.astype(np.float32)  # жилая площадь
y = df[df.columns[11]].values.astype(np.float32) # цена на жилье

# reshape to matrix
X = X.reshape(len(X), 1)

# %%
plt.figure(figsize=(10, 7))

plt.scatter(X, y)
plt.xlabel('Жилая площадь (тыс. кв.футов)', fontsize=12)
plt.ylabel('Стоимость', fontsize=12)
plt.show()

# %% [markdown]
# вспомогательные функции

# %%
def pred(x, w):
    '''
    make predictions
    '''
    return w.dot(x.T)

def mse(y_pred, y):
    '''
    calculate mean squared error
    '''
    return (y_pred-y).T.dot(y_pred-y)/len(y_pred)

# %% [markdown]
# ### Построим зависимость величины ошибки от параметра w1
#
# Гипотеза: $h_w(x)=w1*x$

# %% [markdown]
# В качестве разных $w1$ возьмем 100 значений на интервале от 0 до 50

# %%
w1 = np.linspace(0,50, num=100, dtype=np.float32)
w1 = w1.reshape((len(w1), 1))

print(w1.shape)
print(X.shape)
#print(X_mat.shape)
# Out:
# (100, 1)
# (28, 1)

# %%
y_pred = pred(X, w1)
mse_x  = [mse(x,y) for x in y_pred]

# %%
plt.figure(figsize=(8, 5))
plt.plot(w1,mse_x, c="r")
plt.ylabel('MSE')
plt.xlabel('Параметр W')
plt.text(7, 1500, 'Гипотеза\n$h_{w}(x)=w_1x$', fontsize=14)
plt.show()

# %% [markdown]
# ## Построим график зависимости ошибки от двух переменных
#
# Гипотеза: $h_w(x)=w0+w1*x$

# %% [markdown]
# В качестве разных $w0$ возьмем 100 значений на интервале от 10 до 50
#
# Построим сетку из значений

# %%
w0 = np.linspace(10,50, num=100, dtype=np.float32)
w0 = w0.reshape((len(w0), 1))


W0, W1 = np.meshgrid(w0, w1)
print('W0 shape: {}'.format(W0.shape))
print('W1 shape: {}'.format(W1.shape))
# Out:
# W0 shape: (100, 100)
# W1 shape: (100, 100)

# %% [markdown]
# Для того, чтобы перемножить матрицу параметров на матрицу признаков, нужно добавить единичный столбец, так как формула:
# $$h_w(x)=w0+w1*x=w0*1+w1*x$$

# %%
X_mat = np.ones((X.shape[0],2))
X_mat[:,1] = X[:,0]

print(X_mat[:5])
# Out:
# [[ 1.          0.99800003]
#  [ 1.          1.5       ]
#  [ 1.          1.17499995]
#  [ 1.          1.23199999]
#  [ 1.          1.12100005]]

# %%
W = np.stack([np.ravel(W0), np.ravel(W1)], axis=1)
print('Weight matrix shape: {}'.format(W.shape))

y_pred_mul = pred(X_mat, W)
print('Predictions shape: {}'.format(y_pred_mul.shape))

cost_vals  = np.array([mse(x,y) for x in y_pred_mul])
cost_vals  = cost_vals.reshape(W0.shape)
print('Cost function values shape: {}'.format(cost_vals.shape))
# Out:
# Weight matrix shape: (10000, 2)
# Predictions shape: (10000, 28)
# Cost function values shape: (100, 100)

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(W0, W1, cost_vals, cmap=plt.cm.Spectral)
ax.set_xlabel('$w_0$', fontsize=14)
ax.set_ylabel('$w_1$', fontsize=14)
ax.set_zlabel('MSE', fontsize=14)
plt.show()
